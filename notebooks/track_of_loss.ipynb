# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
training_vae = pd.read_csv('/home/juandres/aml/CheXBias/reports/VAE/mse_loss.csv')

# %%
training_vae.columns = ['Reconstruction','KL','Loss']
training_vae['Loss'].plot()
training_vae['Reconstruction'].plot()
# Out:
# <Axes: >
